# %% [markdown]
# # Exemples de fonctions Pandas utiles pour le TP 1

# %% [markdown]
# ## Importations des librairies utiles

# %%
import numpy as np
import pandas as pd

print('numpy %s, pandas %s'%(np.__version__,pd.__version__))
# Out:
# numpy 1.18.1, pandas 0.25.0

# %% [markdown]
# ## Creation depuis un CSV et affichage d'un Dataframe Pandas

# %%
my_dataframe = pd.read_csv('Data/iris.csv', dtype={'id_Iris': np.int})
my_dataframe
# Out:
#      id_Iris  Longueur Sépale (cm)  Largeur Sépale (cm)  Longueur Pétale (cm)  \
# 0         23                   NaN                  NaN                   1.4
# 1        104                   4.9                  3.0                   1.4
# 2         18                   4.7                  3.2                   1.3
# 3         49                   4.6                  3.1                   1.5
# 4        123                   5.0                  3.6                   1.4
# ..       ...                   ...                  ...                   ...
# 145      124                   6.7                  3.0                   5.2
# 146       44                   6.3                  2.5                   5.0
# 147       69                   6.5                  3.0                   NaN
# 148       56                   6.2                  3.4                   5.4
# 149        5                   5.9                  3.0                   5.1
#
#      Largeur Pétale (cm)  Type Iris
# 0                    0.2          0
# 1                    0.2          0
# 2                    0.2          0
# 3                    0.2          0
# 4                    0.2          0
# ..                   ...        ...
# 145                  2.3          2
# 146                  1.9          2
# 147                  2.0          2
# 148                  2.3          2
# 149                  1.8          2
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Quelques Affichages du dataframe

# %%
my_dataframe.sample(5)
# Out:
#      id_Iris  Longueur Sépale (cm)  Largeur Sépale (cm)  Longueur Pétale (cm)  \
# 90        40                   5.5                  2.6                   4.4
# 7        116                   5.0                  3.4                   1.5
# 112       72                   6.8                  3.0                   5.5
# 82        21                   5.8                  2.7                   3.9
# 69        97                   5.6                  2.5                   3.9
#
#      Largeur Pétale (cm)  Type Iris
# 90                   NaN          1
# 7                    0.2          0
# 112                  2.1          2
# 82                   1.2          1
# 69                   1.1          1

# %%
my_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
# id_Iris                 150 non-null int32
# Longueur Sépale (cm)    142 non-null float64
# Largeur Sépale (cm)     142 non-null float64
# Longueur Pétale (cm)    143 non-null float64
# Largeur Pétale (cm)     146 non-null float64
# Type Iris               150 non-null int64
# dtypes: float64(4), int32(1), int64(1)
# memory usage: 6.6 KB

# %%
my_dataframe.mean()
# Out:
# id_Iris                 74.500000
# Longueur Sépale (cm)     5.846479
# Largeur Sépale (cm)      3.049296
# Longueur Pétale (cm)     3.756643
# Largeur Pétale (cm)      1.208219
# Type Iris                1.000000
# dtype: float64

# %%
my_dataframe.dtypes
# Out:
# id_Iris                   int32
# Longueur Sépale (cm)    float64
# Largeur Sépale (cm)     float64
# Longueur Pétale (cm)    float64
# Largeur Pétale (cm)     float64
# Type Iris                 int64
# dtype: object

# %% [markdown]
# ## Transformation d'une colonne en index

# %%
my_dataframe.set_index('id_Iris',inplace=True)
my_dataframe
# Out:
#          Longueur Sépale (cm)  Largeur Sépale (cm)  Longueur Pétale (cm)  \
# id_Iris
# 23                        NaN                  NaN                   1.4
# 104                       4.9                  3.0                   1.4
# 18                        4.7                  3.2                   1.3
# 49                        4.6                  3.1                   1.5
# 123                       5.0                  3.6                   1.4
# ...                       ...                  ...                   ...
# 124                       6.7                  3.0                   5.2
# 44                        6.3                  2.5                   5.0
# 69                        6.5                  3.0                   NaN
# 56                        6.2                  3.4                   5.4
# 5                         5.9                  3.0                   5.1
#
#          Largeur Pétale (cm)  Type Iris
# id_Iris
# 23                       0.2          0
# 104                      0.2          0
# 18                       0.2          0
# 49                       0.2          0
# 123                      0.2          0
# ...                      ...        ...
# 124                      2.3          2
# 44                       1.9          2
# 69                       2.0          2
# 56                       2.3          2
# 5                        1.8          2
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Tri selon l'index

# %%
my_dataframe.sort_index(inplace=True) #Inplace permet de conserver les modification du DataFrame
my_dataframe
# Out:
#          Longueur Sépale (cm)  Largeur Sépale (cm)  Longueur Pétale (cm)  \
# id_Iris
# 0                         4.9                  3.1                   1.5
# 1                         5.3                  3.7                   1.5
# 2                         6.7                  3.1                   4.4
# 3                         5.0                  3.0                   1.6
# 4                         5.7                  NaN                   4.2
# ...                       ...                  ...                   ...
# 145                       6.5                  2.8                   4.6
# 146                       6.0                  2.2                   4.0
# 147                       4.6                  3.4                   1.4
# 148                       7.3                  2.9                   NaN
# 149                       6.8                  3.2                   5.9
#
#          Largeur Pétale (cm)  Type Iris
# id_Iris
# 0                        0.2          0
# 1                        0.2          0
# 2                        1.4          1
# 3                        0.2          0
# 4                        1.3          1
# ...                      ...        ...
# 145                      1.5          1
# 146                      1.0          1
# 147                      0.3          0
# 148                      1.8          2
# 149                      2.3          2
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Sélection d'une colonne de Dataframe

# %%
my_dataframe['Largeur Sépale (cm)']
# Out:
# id_Iris
# 0      3.1
# 1      3.7
# 2      3.1
# 3      3.0
# 4      NaN
#       ...
# 145    2.8
# 146    2.2
# 147    3.4
# 148    2.9
# 149    3.2
# Name: Largeur Sépale (cm), Length: 150, dtype: float64

# %% [markdown]
# ## Sélection d'une sous-partie de Dataframe (Slice) avec loc

# %%
my_dataframe.loc[124:128,'Largeur Sépale (cm)':'Largeur Pétale (cm)']
# Out:
#          Largeur Sépale (cm)  Longueur Pétale (cm)  Largeur Pétale (cm)
# id_Iris
# 124                      3.0                   5.2                  2.3
# 125                      3.5                   NaN                  0.3
# 126                      2.7                   5.3                  1.9
# 127                      3.1                   1.6                  0.2
# 128                      2.3                   4.4                  1.3

# %%
mon_petit_dataframe = my_dataframe.loc[145:,['Longueur Sépale (cm)','Longueur Pétale (cm)','Type Iris']]
mon_petit_dataframe
# Out:
#          Longueur Sépale (cm)  Longueur Pétale (cm)  Type Iris
# id_Iris
# 145                       6.5                   4.6          1
# 146                       6.0                   4.0          1
# 147                       4.6                   1.4          0
# 148                       7.3                   NaN          2
# 149                       6.8                   5.9          2

# %% [markdown]
# ## Filtre

# %%
mon_petit_dataframe[mon_petit_dataframe['Longueur Pétale (cm)']>4]
# Out:
#          Longueur Sépale (cm)  Longueur Pétale (cm)  Type Iris
# id_Iris
# 145                       6.5                   4.6          1
# 149                       6.8                   5.9          2

# %% [markdown]
# ## Modification en masse (Vectorisation)

# %%
mon_petit_dataframe * 2
# Out:
#          Longueur Sépale (cm)  Longueur Pétale (cm)  Type Iris
# id_Iris
# 145                      13.0                   9.2          2
# 146                      12.0                   8.0          2
# 147                       9.2                   2.8          0
# 148                      14.6                   NaN          4
# 149                      13.6                  11.8          4

# %%
mon_petit_dataframe['Longueur Pétale (cm)'] = mon_petit_dataframe['Longueur Pétale (cm)'] -1
mon_petit_dataframe
# Out:
#          Longueur Sépale (cm)  Longueur Pétale (cm)  Type Iris
# id_Iris
# 145                       6.5                   3.6          1
# 146                       6.0                   3.0          1
# 147                       4.6                   0.4          0
# 148                       7.3                   NaN          2
# 149                       6.8                   4.9          2

# %% [markdown]
# ## Conversion en Numpy (nécessaire car attendu par scikit)

# %%
my_array=mon_petit_dataframe.values
print(type(my_array))
my_array
# Out:
# <class 'numpy.ndarray'>
# array([[6.5, 3.6, 1. ],
#        [6. , 3. , 1. ],
#        [4.6, 0.4, 0. ],
#        [7.3, nan, 2. ],
#        [6.8, 4.9, 2. ]])

# %% [markdown]
# ## Fonction GroupBy

# %%
mon_petit_dataframe[['Longueur Sépale (cm)', 'Longueur Pétale (cm)','Type Iris']].groupby(['Type Iris'])

# %%
mon_petit_dataframe[['Longueur Sépale (cm)', 'Longueur Pétale (cm)','Type Iris']].groupby(['Type Iris']).mean()
# Out:
#            Longueur Sépale (cm)  Longueur Pétale (cm)
# Type Iris
# 0                          4.60                   0.4
# 1                          6.25                   3.3
# 2                          7.05                   4.9

# %%
mon_petit_dataframe[['Longueur Sépale (cm)', 'Longueur Pétale (cm)','Type Iris']].groupby(['Type Iris']).max()
# Out:
#            Longueur Sépale (cm)  Longueur Pétale (cm)
# Type Iris
# 0                           4.6                   0.4
# 1                           6.5                   3.6
# 2                           7.3                   4.9

# %% [markdown]
# ## Fonction qcut and cut

# %%
my_dataframe['CategoricalLgPetale'] = pd.qcut(my_dataframe['Longueur Pétale (cm)'],5)
my_dataframe.head(3)
# Out:
#          Longueur Sépale (cm)  Largeur Sépale (cm)  Longueur Pétale (cm)  \
# id_Iris
# 0                         4.9                  3.1                   1.5
# 1                         5.3                  3.7                   1.5
# 2                         6.7                  3.1                   4.4
#
#          Largeur Pétale (cm)  Type Iris CategoricalLgPetale
# id_Iris
# 0                        0.2          0        (0.999, 1.5]
# 1                        0.2          0        (0.999, 1.5]
# 2                        1.4          1         (3.9, 4.62]

# %%
pd.qcut(my_dataframe['Longueur Pétale (cm)'],5).value_counts()
# Out:
# (0.999, 1.5]    35
# (4.62, 5.3]     29
# (5.3, 6.9]      28
# (3.9, 4.62]     28
# (1.5, 3.9]      23
# Name: Longueur Pétale (cm), dtype: int64

# %%
my_dataframe['CategoricalLgPetale'] = pd.cut(my_dataframe['Longueur Pétale (cm)'],5)
my_dataframe.head(3)
# Out:
#          Longueur Sépale (cm)  Largeur Sépale (cm)  Longueur Pétale (cm)  \
# id_Iris
# 0                         4.9                  3.1                   1.5
# 1                         5.3                  3.7                   1.5
# 2                         6.7                  3.1                   4.4
#
#          Largeur Pétale (cm)  Type Iris CategoricalLgPetale
# id_Iris
# 0                        0.2          0       (0.994, 2.18]
# 1                        0.2          0       (0.994, 2.18]
# 2                        1.4          1        (3.36, 4.54]

# %%
pd.cut(my_dataframe['Longueur Pétale (cm)'],5).value_counts()
# Out:
# (0.994, 2.18]    47
# (4.54, 5.72]     46
# (3.36, 4.54]     33
# (5.72, 6.9]      14
# (2.18, 3.36]      3
# Name: Longueur Pétale (cm), dtype: int64

# %% [markdown]
# ## Fonction map

# %%
my_dataframe['label_iris'] =  my_dataframe["Type Iris"].map(
    {0:'Versicolor',
     1:'Setosa',
     2:'Virginica',
    }
)
my_dataframe
# Out:
#          Longueur Sépale (cm)  Largeur Sépale (cm)  Longueur Pétale (cm)  \
# id_Iris
# 0                         4.9                  3.1                   1.5
# 1                         5.3                  3.7                   1.5
# 2                         6.7                  3.1                   4.4
# 3                         5.0                  3.0                   1.6
# 4                         5.7                  NaN                   4.2
# ...                       ...                  ...                   ...
# 145                       6.5                  2.8                   4.6
# 146                       6.0                  2.2                   4.0
# 147                       4.6                  3.4                   1.4
# 148                       7.3                  2.9                   NaN
# 149                       6.8                  3.2                   5.9
#
#          Largeur Pétale (cm)  Type Iris  label_iris
# id_Iris
# 0                        0.2          0  Versicolor
# 1                        0.2          0  Versicolor
# 2                        1.4          1      Setosa
# 3                        0.2          0  Versicolor
# 4                        1.3          1      Setosa
# ...                      ...        ...         ...
# 145                      1.5          1      Setosa
# 146                      1.0          1      Setosa
# 147                      0.3          0  Versicolor
# 148                      1.8          2   Virginica
# 149                      2.3          2   Virginica
#
# [150 rows x 6 columns]

# %% [markdown]
# ## Filtre de valeurs

# %%
my_dataframe.loc[my_dataframe["Type Iris"]==2][0:20]
# Out:
#          Longueur Sépale (cm)  Largeur Sépale (cm)  Longueur Pétale (cm)  \
# id_Iris
# 5                         5.9                  3.0                   5.1
# 9                         6.7                  3.3                   5.7
# 13                        5.8                  2.7                   5.1
# 14                        7.7                  2.8                   6.7
# 16                        7.2                  3.0                   5.8
# 25                        7.9                  3.8                   6.4
# 26                        7.7                  3.0                   NaN
# 29                        6.7                  3.1                   5.6
# 32                        6.5                  3.2                   5.1
# 34                        6.0                  2.2                   5.0
# 36                        7.6                  3.0                   6.6
# 37                        6.9                  NaN                   5.1
# 41                        6.1                  3.0                   4.9
# 44                        6.3                  2.5                   5.0
# 45                        6.1                  2.6                   5.6
# 52                        7.1                  3.0                   5.9
# 53                        6.7                  2.5                   5.8
# 56                        6.2                  3.4                   5.4
# 57                        5.6                  2.8                   4.9
# 58                        6.4                  3.1                   5.5
#
#          Largeur Pétale (cm)  Type Iris label_iris
# id_Iris
# 5                        1.8          2  Virginica
# 9                        2.1          2  Virginica
# 13                       1.9          2  Virginica
# 14                       2.0          2  Virginica
# 16                       1.6          2  Virginica
# 25                       2.0          2  Virginica
# 26                       2.3          2  Virginica
# 29                       2.4          2  Virginica
# 32                       2.0          2  Virginica
# 34                       1.5          2  Virginica
# 36                       2.1          2  Virginica
# 37                       2.3          2  Virginica
# 41                       1.8          2  Virginica
# 44                       1.9          2  Virginica
# 45                       1.4          2  Virginica
# 52                       2.1          2  Virginica
# 53                       1.8          2  Virginica
# 56                       2.3          2  Virginica
# 57                       2.0          2  Virginica
# 58                       1.8          2  Virginica

# %% [markdown]
# ## Filtre et Remplacement de valeurs

# %%
my_dataframe.loc[
    my_dataframe["Largeur Pétale (cm)"]>2, # Lignes
                "label_iris"
    ]= 'Grand Virginica'
my_dataframe[0:20]
# Out:
#          Longueur Sépale (cm)  Largeur Sépale (cm)  Longueur Pétale (cm)  \
# id_Iris
# 0                         4.9                  3.1                   1.5
# 1                         5.3                  3.7                   1.5
# 2                         6.7                  3.1                   4.4
# 3                         5.0                  3.0                   1.6
# 4                         5.7                  NaN                   4.2
# 5                         5.9                  3.0                   5.1
# 6                         6.1                  2.8                   4.0
# 7                         5.4                  3.4                   1.7
# 8                         5.6                  3.0                   4.5
# 9                         6.7                  3.3                   5.7
# 10                        4.6                  3.2                   1.4
# 11                        5.0                  2.3                   3.3
# 12                        5.5                  4.2                   1.4
# 13                        5.8                  2.7                   5.1
# 14                        7.7                  2.8                   6.7
# 15                        6.3                  3.3                   4.7
# 16                        7.2                  3.0                   5.8
# 17                        6.6                  3.0                   4.4
# 18                        4.7                  3.2                   1.3
# 19                        NaN                  2.6                   4.0
#
#          Largeur Pétale (cm)  Type Iris       label_iris
# id_Iris
# 0                        0.2          0       Versicolor
# 1                        0.2          0       Versicolor
# 2                        1.4          1           Setosa
# 3                        0.2          0       Versicolor
# 4                        1.3          1           Setosa
# 5                        1.8          2        Virginica
# 6                        1.3          1           Setosa
# 7                        0.2          0       Versicolor
# 8                        1.5          1           Setosa
# 9                        2.1          2  Grand Virginica
# 10                       0.2          0       Versicolor
# 11                       1.0          1           Setosa
# 12                       0.2          0       Versicolor
# 13                       1.9          2        Virginica
# 14                       2.0          2        Virginica
# 15                       1.6          1           Setosa
# 16                       1.6          2        Virginica
# 17                       1.4          1           Setosa
# 18                       0.2          0       Versicolor
# 19                       1.2          1           Setosa

# %% [markdown]
# ## Remplir les valeurs manquantes

# %%
mon_petit_dataframe.fillna(0) # Ajouter le paramètre inplace=True pour que le DataFrame soit modifié
# Out:
#          Longueur Sépale (cm)  Longueur Pétale (cm)  Type Iris
# id_Iris
# 145                       6.5                   3.6          1
# 146                       6.0                   3.0          1
# 147                       4.6                   0.4          0
# 148                       7.3                   0.0          2
# 149                       6.8                   4.9          2

# %%
mon_petit_dataframe
# Out:
#          Longueur Sépale (cm)  Longueur Pétale (cm)  Type Iris
# id_Iris
# 145                       6.5                   3.6          1
# 146                       6.0                   3.0          1
# 147                       4.6                   0.4          0
# 148                       7.3                   NaN          2
# 149                       6.8                   4.9          2

# %% [markdown]
# ## columns et drop

# %%
print(list(my_dataframe.columns.values))
my_dataframe = my_dataframe.drop('CategoricalLgPetale', axis=1)
print(list(my_dataframe.columns.values))
# Out:
# ['Longueur Sépale (cm)', 'Largeur Sépale (cm)', 'Longueur Pétale (cm)', 'Largeur Pétale (cm)', 'Type Iris', 'CategoricalLgPetale']
# ['Longueur Sépale (cm)', 'Largeur Sépale (cm)', 'Longueur Pétale (cm)', 'Largeur Pétale (cm)', 'Type Iris']

# %% [markdown]
# ## Mise en Forme

# %%
from IPython.display import Markdown, display, HTML

display(Markdown('<span style="color:blue;font-weight:bold">Ceci est le titre</span>'))
display(HTML(mon_petit_dataframe.to_html()))
display(Markdown('<span style="color:blue;font-weight:bold">----- Fin ----- </span>'))
# Out:
# <span style="color:blue;font-weight:bold">Ceci est le titre</span>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Longueur Sépale (cm)</th>
#       <th>Longueur Pétale (cm)</th>
#       <th>Type Iris</th>
#     </tr>
#     <tr>
#       <th>id_Iris</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>145</th>
#       <td>6.5</td>
#       <td>3.6</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>146</th>
#       <td>6.0</td>
#       <td>3.0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>147</th>
#       <td>4.6</td>
#       <td>0.4</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>148</th>
#       <td>7.3</td>
#       <td>NaN</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>149</th>
#       <td>6.8</td>
#       <td>4.9</td>
#       <td>2</td>
#     </tr>
#   </tbody>
# </table>
# <span style="color:blue;font-weight:bold">----- Fin ----- </span>
